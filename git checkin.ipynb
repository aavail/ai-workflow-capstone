# %%
import numpy as np # linear algebra
import time
import cv2
import os
from matplotlib import pyplot as plt
from tqdm import tqdm_notebook
from glob import glob
import multiprocessing
from google.colab import drive
drive.mount('/content/gdrive/')
os.chdir('/content/gdrive/My Drive/github')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# !git clone https://github.com/leooooliu/ai-workflow-capstone.git
# Out:
# fatal: destination path 'ai-workflow-capstone' already exists and is not an empty directory.

# %%
ls
# Out:
# cs-production/  cs-train/  README.md  solution-guidance/

# %%
ls
# Out:
# ai-workflow-capstone/  Images_containing_text1.ipynb
